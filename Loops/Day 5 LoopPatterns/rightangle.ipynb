# %%
rows = 5
for i in range(1, rows+5):
    for j in range(i-1):
        print(' ', end = '')
    for k in range((rows-i)+1):
        print('*', end = '')
    print()
# Out:
# *****
#  ****
#   ***
#    **
#     *

# %%
rows = 5 
for i in range(1, rows+1):
    for j in range(i):
        print('*', end = '')
    print()
# Out:
# *
# **
# ***
# ****
# *****

# %%
rows = 5 
for i in range(1,rows+1):
    for j in range(rows-i):
        print(' ', end = '')
    for k in range(i):
        print('*', end = '')
    print()
# Out:
#     *
#    **
#   ***
#  ****
# *****
